# %% [markdown]
# <a href="https://colab.research.google.com/github/rridss/NLP/blob/main/nlp4th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##EXPERIMENT-4:
# ##Do text mining on extract data and Accessing text corpus

# %%
# Install necessary libraries
# !pip install nltk
# !pip install wordcloud
# !pip install matplotlib

# Import libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import string
nltk.download('punkt')
nltk.download('stopwords')

# Sample text
text = """
Natural language processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data.
It is a complex field that draws on many disciplines, including cognitive science, linguistics, computer science, and artificial intelligence.
NLP technologies are used in a wide range of applications, such as machine translation, speech recognition, and text summarization.
"""
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Tokenization
tokens = word_tokenize(text.lower())

# Removing stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in stripped_tokens if word not in stop_words]

# Calculating word frequency
fdist = FreqDist(filtered_tokens)

# Top 10 frequent words
top_words = fdist.most_common(10)
print("Top 10 frequent words with their frequency:")
for word, freq in top_words:
    print(f"{word}: {freq}")
# Out:
# Top 10 frequent words with their frequency:
# : 15
# language: 3
# science: 3
# natural: 2
# nlp: 2
# linguistics: 2
# computer: 2
# artificial: 2
# intelligence: 2
# computers: 2

# %%
# Creating word cloud
wordcloud = WordCloud(width=800, height=400, background_color='orchid', colormap='viridis').generate(" ".join(filtered_tokens))

# Displaying word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Creating a bar graph of the top 10 frequent words
plt.figure(figsize=(12, 6))
plt.bar([word for word, freq in top_words], [freq for word, freq in top_words], color='purple')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Frequent Words')
plt.xticks(rotation=45)
plt.show()
